# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt


# with open('./elem_yposi_ystress.csv') as f:
#     reader = csv.reader(f)
#     data = [row for row in reader]
names = ['yposi', 'ystress']
df = pd.read_csv('./elem_yposi_ystress.csv', names=names)
print(df)
# Out:
#        yposi   ystress
# 0   3.333330 -0.223053
# 1   8.333325 -0.224726
# 2  13.333320 -0.235480
# 3  18.333314 -0.257481
# 4  23.333308 -0.296532
# 5  28.333301 -0.363479
# 6  33.333293 -0.478102
# 7  38.333283 -0.676673
# 8  43.333272 -1.023556
# 9  48.333257 -1.539047

# %%
plt.figure()
df.plot(x = 'yposi', y = 'ystress')
plt.savefig('./yposi_ystress.png')
